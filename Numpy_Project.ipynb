# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Q 1
data_file ='KAG_Conversion_Data.csv'

# %%
data = np.genfromtxt(data_file, delimiter=",", skip_header=1)
data_string = np.genfromtxt(data_file, delimiter=",", skip_header=1, dtype = str)
ad_id = data[:,0]
xyzcampaignid = data[:,1]
fbcampaignid = data[:,2]
age = data_string[:,3]
gender = data_string[:,4]
interest = data[:,5]
impressions = data[:,6]
clicks = data[:,7]
spent = data[:,8]
total_conversion = data[:,9]
approved_conversion = data[:,10]

# %%
# Q 2
unique,frequency = np.unique(xyzcampaignid, return_counts = True)

# %%
print(unique)
# Out:
# [ 916.  936. 1178.]

# %%
print("There are {} unique campaign ids.".format(len(unique)))
# Out:
# There are 3 unique campaign ids.

# %%
print(frequency)
# Out:
# [ 54 464 625]

# %%
# Q 3
print(np.unique(age))
# Out:
# ['30-34' '35-39' '40-44' '45-49']

# %%
# Q 4
spent.min()
# Out:
# 0.0

# %%
spent.max()
# Out:
# 639.9499981

# %%
spent.mean()
# Out:
# 51.36065613141295

# %%
# Q 5
m = clicks.max()
ad_id[clicks == m]
# Out:
# array([1121814.])

# %%
# Q 6
x = approved_conversion[clicks == m]
print(x)
# Out:
# [13.]

# %%
y = approved_conversion.max()
print(y)
# Out:
# 21.0

# %%
if (x!=y):
  st = "Not the max number of puchases"
  print(st)
# Out:
# Not the max number of puchases

# %%
#Q 7
s1 = approved_conversion == approved_conversion.max()
ad_id[s1]
# Out:
# array([1121104.])

# %%
xyzcampaignid[s1]
# Out:
# array([1178.])

# %%
fbcampaignid[s1]
# Out:
# array([144533.])

# %%
age[s1]
# Out:
# array(['30-34'], dtype='<U11')

# %%
gender[s1]
# Out:
# array(['M'], dtype='<U11')

# %%
interest[s1]
# Out:
# array([16.])

# %%
impressions[s1]
# Out:
# array([2080666.])

# %%
clicks[s1]
# Out:
# array([202.])

# %%
spent[s1]
# Out:
# array([360.1500015])

# %%
total_conversion[s1]
# Out:
# array([40.])

# %%
approved_conversion[s1]
# Out:
# array([21.])
